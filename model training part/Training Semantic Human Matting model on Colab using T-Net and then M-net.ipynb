# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
% ls
# Out:
#  clean.py
#  data/
#  model/
#  photo.jpg
#  pre_trained/
#  __pycache__/
#  test/
# 'test image portrait matting using pre-trained model.pptx'
#  test.py
#  test.sh
#  train1.py
#  train1.sh
#  train2.py
#  train2.sh
#  train3.py
#  train_fine_tuing.py
# 'training model result'/
#  train.py
#  train.sh
#  webcam.py
#  webcam.sh

# %%
! nvidia-smi
# Out:
# Tue Jul 27 23:15:31 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from numba import cuda

@cuda.jit
def gpu_sqrt_kernel(x, out):
  idx = cuda.grid(1)
  out[idx] = math.sqrt(x[idx])

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# ''

# %%
# %cd gdrive/My\ Drive/Colab\ Notebooks/real_time_portrait_matting4811/
# Out:
# /content/gdrive/My Drive/Colab Notebooks/real_time_portrait_matting4811

# %%
cat /proc/cpuinfo | grep 'model name' | sort | uniq
# Out:
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz

# %%
cat /proc/cpuinfo | grep 'physical id' | sort | uniq | wc -l
# Out:
# 1

# %%
cat /proc/cpuinfo |grep "cores"|uniq|awk '{print $4}'
# Out:
# 1

# %%
cat /proc/cpuinfo |grep "processor"|wc -l
# Out:
# 2

# %%
cat /proc/cpuinfo |grep "processor"|wc -l # 查看逻辑CPU的个数
# Out:
# 2

# %%
cat /proc/cpuinfo |grep "processor"|wc -l

# %%
# %%shell
#
# python train-Tnet.py --nEpochs=500 --patch_size=256 --lr=1e-4 --gpus='0,1,2,3' --nThreads=4 --train_batch=32 --train_phase='pre_train_t_net'

# %%
# %%shell
#
# python train-Mnet.py --nEpochs=810 --patch_size=256 --lr=1e-5 --gpus='0,1,2,3' --nThreads=4 --train_batch=32 --train_phase='end_to_end'
